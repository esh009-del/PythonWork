# %%
numbers=[1,2,3,4,6] #input list of numbers
def square_the_number(num): #
    return num **2

squares_map=map(square_the_number, numbers)
squares_list=list(squares_map)
print(squares_list)
# Out:
# [1, 4, 9, 16, 36]
